# %% [markdown]
# <a href="https://colab.research.google.com/github/azuuuake/vpr-language-fusion/blob/main/session_init.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# CELL 1 — Clone all repos

# !git clone https://github.com/azuuuake/vpr-language-fusion
# !git clone https://github.com/gmberton/auto_VPR
# !git clone https://github.com/oferidan1/LaVPR
# !git clone https://github.com/gmberton/VPR-datasets-downloader
# Out:
# Cloning into 'vpr-language-fusion'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.
# Cloning into 'auto_VPR'...
# remote: Enumerating objects: 432, done.
# remote: Counting objects: 100% (220/220), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 432 (delta 189), reused 156 (delta 156), pack-reused 212 (from 1)
# Receiving objects: 100% (432/432), 1.35 MiB | 9.49 MiB/s, done.
# Resolving deltas: 100% (260/260), done.
# Cloning into 'LaVPR'...
# remote: Enumerating objects: 348, done.
# remote: Counting objects: 100% (58/58), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 348 (delta 17), reused 40 (delta 6), pack-reused 290 (from 1)
# Receiving objects: 100% (348/348), 186.40 MiB | 40.22 MiB/s, done.
# Resolving deltas: 100% (42/42), done.
# Cloning into 'VPR-datasets-downloader'...
# ...

# %%
# CELL 2 — Install all dependencies

# !pip install torch torchvision --index-url https://download.pytorch.org/whl/cu118 -q
# !pip install sentence-transformers numpy pandas scipy matplotlib tqdm faiss-cpu -q
# !pip install -r LaVPR/requirements.txt -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 93.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.3/266.3 kB 7.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.0/557.0 kB 22.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 825.8/825.8 kB 48.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 55.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 69.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.8/127.8 kB 10.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 70.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 100.9 MB/s eta 0:00:00
# ...

# %%
# CELL 3 — Mount Drive and verify GPU

from google.colab import drive
drive.mount('/content/drive')

RESULTS_DIR = '/content/drive/MyDrive/vpr_research/results/'
FIGURES_DIR = '/content/drive/MyDrive/vpr_research/figures/'
EMBED_DIR   = '/content/drive/MyDrive/vpr_research/embeddings/'
NOTES_DIR   = '/content/drive/MyDrive/vpr_research/notes/'

import torch

if torch.cuda.is_available():
    print(f"GPU ready: {torch.cuda.get_device_name(0)}")
    print(f"VRAM: {torch.cuda.get_device_properties(0).total_memory/1e9:.1f} GB")
else:
    print("No GPU — CPU mode. Change Runtime to GPU if needed.")
# Out:
# Mounted at /content/drive
# No GPU — CPU mode. Change Runtime to GPU if needed.
